# %% [markdown]
# Imported all the necessary libraries for data preprocessing.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Installed the openpyxl package, used for reading Excel files in Python.

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (3.1.4)
# Requirement already satisfied: et-xmlfile in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from openpyxl) (1.1.0)
# WARNING: Ignoring invalid distribution -yspark (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -yspark (c:\users\user\appdata\local\programs\python\python39\lib\site-packages)

# %% [markdown]
# Loaded the dataset into a Pandas DataFrame.

# %%
df = pd.read_excel(r"C:\Users\USER\Documents\Data_Epic\Week-2\Online_Retail.xlsx")

# %% [markdown]
# Displayed the top rows of the DataFrame using the head() function to get an overview of the columns and data.

# %%
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %% [markdown]
# Displayed information about the DataFrame's columns using the info() function, which shows the data type and count of non-null values for each column, helping to identify columns that require preprocessing and potential issues with missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# Checked the total number of rows in the DataFrame using the shape attribute

# %%
df.shape[0]
# Out:
# 541909

# %% [markdown]
# Checked the number of missing values (empty rows) in each column

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# The customerID column has missing values, since it is a crucial column, it cannot be replaced with random values.
# I will drop the rows instead.

# %%
filtered_df = df.dropna(subset=['CustomerID'])

# %% [markdown]
# I checked if there are still empty rows

# %%
filtered_df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# After dropping rows with missing values in the CustomerID column, we have successfully removed all missing values from the dataset.
#
# Next step: Checked the data types of each column using the dtypes attribute, to ensure correct data types

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %% [markdown]
# Converted the Customer_ID column from object datatype to integer datatype using the astype method, to ensure consistency in datatype for identifier columns.

# %%
filtered_df['CustomerID'] = filtered_df['CustomerID'].astype(int)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18956\2756022511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['CustomerID'] = filtered_df['CustomerID'].astype(int)

# %% [markdown]
# Before converting the InvoiceNo column to an Integer, I discovered that it contained invalid entries, specifically codes starting with letters. Next, I will identify and count these invalid codes.

# %%
import re
pattern = r'^[a-zA-Z]'
pattern = re.compile(pattern)

list_of_invalid_no = []
for no in filtered_df['InvoiceNo']:
    invalid_no = pattern.findall(str(no))
    if invalid_no:
        list_of_invalid_no.append(no)


print(list_of_invalid_no)
print(len(list_of_invalid_no))
# Out:
# ['C536379', 'C536383', 'C536391', 'C536391', 'C536391', 'C536391', 'C536391', 'C536391', 'C536391', 'C536506', 'C536543', 'C536543', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536548', 'C536606', 'C536622', 'C536625', 'C536642', 'C536734', 'C536734', 'C536737', 'C536757', 'C536758', 'C536760', 'C536760', 'C536807', 'C536807', 'C536812', 'C536812', 'C536812', 'C536812', 'C536812', 'C536812', 'C536814', 'C536814', 'C536814', 'C536814', 'C536814', 'C536815', 'C536815', 'C536816', 'C536817', 'C536817', 'C536818', 'C536820', 'C536820', 'C536820', 'C536820', 'C536822', 'C536822', 'C536825', 'C536825', 'C536826', 'C536826', 'C536827', 'C536828', 'C536828', 'C536829', 'C536850', 'C536850', 'C536850', 'C536850', 'C536850', 'C536853', 'C536854', 'C536854', 'C536854', 'C536855', 'C536978', 'C536979', 'C536979', 'C537024', 'C537039', 'C537039', 'C537039', 'C537043', 'C537043', 'C537132', 'C537132', 'C537132', 'C537132', 'C537132', 'C537132', 'C537143', 'C537157', 'C537164', 'C537203', 'C537203', 'C537232', 'C537234', 'C537314', 'C537320', 'C537333', 'C537373', 'C537379', 'C537383', 'C537383', 'C537383', 'C537398', 'C537402', 'C537402', 'C537402', 'C537402', 'C537402', 'C537402', 'C537406', 'C537406', 'C537406', 'C537406', 'C537408', 'C537408', 'C537413', 'C537414', 'C537414', 'C537416', 'C537417', 'C537431', 'C537444', 'C537445', 'C537530', 'C537530', 'C537530', 'C537596', 'C537597', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537602', 'C537611', 'C537656', 'C537677', 'C537684', 'C537684', 'C537746', 'C537746', 'C537746', 'C537756', 'C537756', 'C537756', 'C537763', 'C537788', 'C537788', 'C537797', 'C537797', 'C537797', 'C537798', 'C537805', 'C537805', 'C537805', 'C537805', 'C537805', 'C537805', 'C537805', 'C537805', 'C537805', 'C537807', 'C537807', 'C537807', 'C537807', 'C537812', 'C537812', 'C537814', 'C537820', 'C537821', 'C537824', 'C537824', 'C537832', 'C537832', 'C537832', 'C537834', 'C537834', 'C537834', 'C537835', 'C537838', 'C537853', 'C537853', 'C537853', 'C537853', 'C537853', 'C537856', 'C537856', 'C537857', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537860', 'C537893', 'C537893', 'C537893', 'C537998', 'C537998', 'C538052', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538059', 'C538062', 'C538062', 'C538062', 'C538062', 'C538062', 'C538066', 'C538075', 'C538081', 'C538082', 'C538083', 'C538083', 'C538084', 'C538084', 'C538085', 'C538085', 'C538085', 'C538088', 'C538089', 'C538091', 'C538098', 'C538099', 'C538099', 'C538100', 'C538102', 'C538103', 'C538105', 'C538105', 'C538109', 'C538109', 'C538110', 'C538111', 'C538112', 'C538112', 'C538114', 'C538115', 'C538115', 'C538115', 'C538115', 'C538118', 'C538118', 'C538118', 'C538119', 'C538119', 'C538119', 'C538121', 'C538122', 'C538123', 'C538123', 'C538123', 'C538124', 'C538124', 'C538124', 'C538164', 'C538314', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538341', 'C538344', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C538350', 'C5383 ...
# 8905

# %% [markdown]
# Next, I removed the letters from the invalid entries in the InvoiceNo column, converting them to a numerical format.

# %%
for no in list_of_invalid_no:
    filtered_df['InvoiceNo'] = filtered_df['InvoiceNo'].replace(no, no[1:])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18956\936924359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['InvoiceNo'] = filtered_df['InvoiceNo'].replace(no, no[1:])

# %% [markdown]
# Now that the invalid entries have been cleaned up, I can convert the datatype of the InvoiceNo column to integer.

# %%
filtered_df['InvoiceNo'] = filtered_df['InvoiceNo'].astype(int)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18956\1246140328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['InvoiceNo'] = filtered_df['InvoiceNo'].astype(int)

# %%
filtered_df.info()
filtered_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  int32
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  int32
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(1), object(3)
# memory usage: 24.8+ MB
#    InvoiceNo StockCode                         Description  Quantity  \
# 0     536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                 WHITE METAL LANTERN         6
# 2     536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom

# %% [markdown]
# Upon reviewing the remaining columns, I noticed that the StockCode column is currently in the wrong datatype and should be converted to integer. Additionally, I found that some entries in this column contain invalid data, specifically letters appearing at the end of the code, which need to be cleaned up before the datatype conversion.

# %% [markdown]
# I identified and counted the StockCode entries with letters at the end.

# %%
def check_invalid_stock_code(stock_code_column):
    pattern = r'[$a-zA-Z]'
    pattern = re.compile(pattern)
    list_of_invalid_stock_code = []
    for code in stock_code_column:
        invalid_stock_code = pattern.findall(str(code))
        if invalid_stock_code:
            list_of_invalid_stock_code.append(code)
    return list_of_invalid_stock_code

invalid_codes = check_invalid_stock_code(filtered_df['StockCode'])
print(len(invalid_codes))
# Out:
# 35809

# %% [markdown]
# I removed the letters from the invalid entries in the StockCode column, leaving only numerical values.

# %%
for code in invalid_codes:
    filtered_df['StockCode'] = filtered_df['StockCode'].replace(code, code[:-1])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18956\2876221238.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['StockCode'] = filtered_df['StockCode'].replace(code, code[:-1])

# %% [markdown]
# Checked if there are still invalid entries in these column

# %%
invalid_codes = check_invalid_stock_code(filtered_df['StockCode'])
print(invalid_codes)
# Out:
# ['POS', '15056B', '15056B', 'POS', 'POS', '15056B', 'C', '15056B', '15056B', 'BANK CHARGE', '15056B', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', '15056B', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'C', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', 'C', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', '15056B', '15056B', 'POS', '15056B', '15056B', 'POS', '15056B', '15056B', 'POS', 'POS', 'POS', '15056B', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', 'POS', '15056B', 'POS', 'C', 'POS', 'POS', '15056B', 'POS', '15056B', 'POS', '15056B', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', '15056B', 'POS', 'POS', '15056B', '15056B', 'C', 'POS', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', '15056B', '15056B', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', '15056B', '15056B', 'POS', '15056B', 'POS', 'POS', 'C', 'POS', '15056B', 'POS', 'BANK CHARGE', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'C', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', '15056B', 'POS', 'POS', '15056B', '15056B', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'C', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', '15056B', '15056B', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', '15056B', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'C', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'C', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', '15056B', 'POS', 'C', 'C', 'POS', 'C', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', '15056B', 'POS', 'POS', 'POS', '15056B', 'POS', 'C', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', '15056B', 'POS', 'C', 'POS', '15056B', 'POS', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'C', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', '15056B', '15056B', 'POS', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'BANK CHARGE', 'C', 'POS', 'POS', '15056B', 'C', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'PAD', '15056B', '15056B', 'POS', 'POS', 'POS', 'C', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'C', 'C', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'C', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'BANK CHARGE', 'C', 'POS', 'POS', '15056B', 'POS', '15056B', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', 'POS', '15056B', 'POS', 'POS', '15056B', 'POS', '15056B', '15056B', 'POS', ' ...

# %% [markdown]
# I still found that some entries in the StockCode column still contained letters at the end. I have now removed these invalid characters, ensuring that only numerical values remain in the column.

# %%
for code in invalid_codes:
    if code[-1].isalpha():
        filtered_df['StockCode'] = filtered_df['StockCode'].replace(code, code[:-1])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18956\373193362.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['StockCode'] = filtered_df['StockCode'].replace(code, code[:-1])

# %% [markdown]
# Checked if there are still any invalid entries

# %%
invalid_codes = check_invalid_stock_code(filtered_df['StockCode'])

print(set(invalid_codes), len(invalid_codes))
# Out:
# {'CR', 'BANK CHARG', 'PA', 'D', 'PO'} 1244

# %% [markdown]
# I created a backup copy of my filtered dataframe at this stage, saving it as a new object, so I can easily revert to this point if needed, in case any subsequent errors arise during further data processing.

# %%
filtered_df_copy = filtered_df.copy()

# %% [markdown]
# I noticed that some non-numeric entries, such as 'BANK CHARG' and 'CR', still remain in the dataset. Since these invalid codes are limited in number, I will remove the corresponding rows from the dataset

# %%
filtered_df = filtered_df.loc[~filtered_df['StockCode'].isin(invalid_codes)]

# %% [markdown]
# Checked if there are still any invalid entries in the StockCode column

# %%
invalid_codes = check_invalid_stock_code(filtered_df['StockCode'])

# %% [markdown]
# Checked if there are any empty strings

# %%
filtered_df.loc[filtered_df['StockCode']== '']
# Out:
#         InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 141        536379              Discount        -1 2010-12-01 09:41:00
# 1423       536540              CARRIAGE         1 2010-12-01 14:05:00
# 2239       536569                Manual         1 2010-12-01 15:35:00
# 2250       536569                Manual         1 2010-12-01 15:35:00
# 6798       536981                Manual         2 2010-12-03 14:26:00
# ...           ...       ...         ...       ...                 ...
# 531432     580956                Manual         4 2011-12-06 14:23:00
# 533082     581009                Manual        -1 2011-12-07 09:15:00
# 534308     581145                Manual        -1 2011-12-07 13:48:00
# 538321     581405                Manual         3 2011-12-08 13:50:00
# 541541     581499                Manual        -1 2011-12-09 10:28:00
#
#         UnitPrice  CustomerID         Country
# 141         27.50       14527  United Kingdom
# 1423        50.00       14911            EIRE
# 2239         1.25       16274  United Kingdom
# 2250        18.95       16274  United Kingdom
# 6798         0.85       14723  United Kingdom
# ...           ...         ...             ...
# 531432       1.25       17841  United Kingdom
# 533082     125.00       16971  United Kingdom
# 534308       9.95       17490  United Kingdom
# 538321       0.42       13521  United Kingdom
# 541541     224.69       15498  United Kingdom
#
# [676 rows x 8 columns]

# %% [markdown]
# I noticed that some entries in the StockCode column are empty strings, which is inconsistent with the expected integer values.

# %%
filtered_df.loc[filtered_df['StockCode']== ''].shape[0]
# Out:
# 676

# %% [markdown]
# I will remove these rows containing empty strings

# %%
filtered_df = filtered_df.loc[filtered_df['StockCode']!= '']

# %% [markdown]
# With all invalid entries removed, I can now safely convert the datatype of the StockCode column to integer (INT)

# %%
filtered_df['StockCode'] = filtered_df['StockCode'].astype(int)

# %% [markdown]
# Next, I will perform a final check on all columns to confirm that they are now in their appropriate datatypes, ensuring that:
#
#
# InvoiceNo is integer (INT)
#
#
# StockCode is integer (INT)
#
#
# And all other columns are in their respective correct datatypes

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    404909 non-null  int32
#  1   StockCode    404909 non-null  int32
#  2   Description  404909 non-null  object
#  3   Quantity     404909 non-null  int64
#  4   InvoiceDate  404909 non-null  datetime64[ns]
#  5   UnitPrice    404909 non-null  float64
#  6   CustomerID   404909 non-null  int32
#  7   Country      404909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(3), int64(1), object(2)
# memory usage: 23.2+ MB

# %% [markdown]
# I will now remove any duplicate rows from the dataframe, preserving only unique records.

# %%
filtered_df.drop_duplicates(inplace=True)

# %% [markdown]
# After removing the duplicate rows and the rows with empty strings in the StockCode column, I will re-check the dataframe to confirm that:
#
#
# All columns are in their appropriate datatypes
#
#
# There are no duplicate rows
#
#
# The StockCode column contains only valid, non-empty integer values

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 399654 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    399654 non-null  int32
#  1   StockCode    399654 non-null  int32
#  2   Description  399654 non-null  object
#  3   Quantity     399654 non-null  int64
#  4   InvoiceDate  399654 non-null  datetime64[ns]
#  5   UnitPrice    399654 non-null  float64
#  6   CustomerID   399654 non-null  int32
#  7   Country      399654 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(3), int64(1), object(2)
# memory usage: 22.9+ MB

# %% [markdown]
# All the columns are now in the appropriate data types and the duplicates have been removed. Now our dataframe is cleaned and ready for any feature extraction we'd like to do.
#
# Now based on the data columns, Additional meaningful features I can create are mainly from the datetime column InvoiceDate, and these features are:
# 1. InvoiceDate DayName
# 2. InvoiceDate MonthName
# 3. InvoiceDate Year
# 4. InvoiceDate Week Of The Month (Week of that date in the current month)

# %%
filtered_df['InvoiceDateMonth'] = filtered_df['InvoiceDate'].dt.month_name()
filtered_df['InvoiceDateYear'] = filtered_df['InvoiceDate'].dt.year
filtered_df['InvoiceDateDay'] = filtered_df['InvoiceDate'].dt.day_name()

# %%
import numpy as np
def get_week_of_month(date):
    first_day = date.replace(day=1)
    day_of_month = date.day
    adjusted_date = first_day.weekday() + day_of_month
    return int(np.ceil(adjusted_date/7.0))

filtered_df['InvoiceDateWeekOfMonth'] = filtered_df['InvoiceDate'].apply(get_week_of_month)

# %% [markdown]
# A quick view of the new dataframe

# %%
filtered_df.head(5)
# Out:
#    InvoiceNo  StockCode                          Description  Quantity  \
# 0     536365      85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365      84406       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365      84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365      84029       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoiceDateMonth  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom         December
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom         December
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom         December
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom         December
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom         December
#
#    InvoiceDateYear InvoiceDateDay  InvoiceDateWeekOfMonth
# 0             2010      Wednesday                       1
# 1             2010      Wednesday                       1
# 2             2010      Wednesday                       1
# 3             2010      Wednesday                       1
# 4             2010      Wednesday                       1

# %% [markdown]
# Now I want to save the cleaned dataset to a new excel file

# %%
filtered_df.to_excel(r"C:\Users\USER\Documents\Data_Epic\Week-2\Online_Retail_Cleaned.xlsx", index=False)
